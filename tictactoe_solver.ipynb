# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torchvision.datasets import MNIST
from torch.utils.data import DataLoader
import random
import pickle
import numpy as np

# %%
class TicTacToe:
    def __init__(self):
        self.board = np.zeros((3, 3))
        self.current_player = 1
    
    def reset(self):
        self.board.fill(0)
        self.current_player = 1
    
    def make_move(self, row, col):
        if self.board[row, col] == 0:
            self.board[row, col] = self.current_player
            return True
        return False
    
    def check_winner(self):
        for player in [-1, 1]:
            if any(np.all(self.board[i, :] == player) for i in range(3)) or \
               any(np.all(self.board[:, i] == player) for i in range(3)) or \
               np.all(np.diag(self.board) == player) or \
               np.all(np.diag(np.fliplr(self.board)) == player):
                return player
        if np.all(self.board != 0):
            return 0 
        return None

    def switch_player(self):
        self.current_player = -1*self.current_player
    
    def print_board(self):
        symbols = {0: ".", 1: "X", -1: "O"}
        print("\n".join(" ".join(symbols[cell] for cell in row) for row in self.board))

# %%
class MLP(nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(9, 18)  # Input layer (9 for the board) to hidden layer
        self.fc2 = nn.Linear(18, 9)   # Hidden layer to output layer (9 possible moves)
        

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        return self.fc2(x)

# %%
def train_model(model, games, optimizer, criterion, episodes=100, epsilon=0.1):
    for episode in range(episodes):
        for state, action, reward in games:
            state_tensor = torch.FloatTensor(state).view(1, -1)
            target = model(state_tensor).detach()
            target[0][action] = reward  # Update Q-value for the taken action

            optimizer.zero_grad()
            output = model(state_tensor)
            loss = criterion(output, target)
            print(f"Loss in episode {episode} is {loss}")
            loss.backward()
            optimizer.step()

# %%
# Self-play logic
def self_play(model, num_games=30):
    games = []
    for _ in range(num_games):
        game = TicTacToe()
        while True:
            state = game.board.flatten().tolist()
            if game.current_player == 1:
                q_values = model(torch.FloatTensor(state)).detach().numpy()
                action = np.argmax(q_values) if random.random() > 0.1 else random.choice(np.flatnonzero(game.board.flatten() == 0))
            else:
                # Random move for player 2 for simplicity
                action = random.choice(np.flatnonzero(game.board.flatten() == 0))

            row, col = divmod(action, 3)
            game.make_move(row, col)
            reward = game.check_winner()
            if reward is not None:
                if reward == 1:  # Player 1 wins
                    games.append((state, action, 1))
                elif reward == 2:  # Player 2 wins
                    games.append((state, action, -1))
                else:  # Draw
                    games.append((state, action, 0))
                break

            game.switch_player()
            # Store the state-action pair
            games.append((state, action, 0))  # Temporary reward until the game ends
    return games

# %%
model = MLP()
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.MSELoss()
    
games = self_play(model, num_games=30)
train_model(model, games, optimizer, criterion, episodes=10)

# Test the trained model
game = TicTacToe()
while True:
    game.print_board()
    if game.current_player == 1:
        state = game.board.flatten().tolist()
        q_values = model(torch.FloatTensor(state)).detach().numpy()
        action = np.argmax(q_values)
        row, col = divmod(action, 3)
    else:
        action = random.choice(np.flatnonzero(game.board.flatten() == 0))
        row, col = divmod(action, 3)

    game.make_move(row, col)
    if game.check_winner() is not None:
        game.print_board()
        print("Winner:", game.check_winner())
        break
    game.switch_player()
# Out:
# Loss in episode 0 is 0.006645164918154478
# Loss in episode 0 is 0.00022522496874444187
# Loss in episode 0 is 0.011672320775687695
# Loss in episode 0 is 0.0004374891286715865
# Loss in episode 0 is 0.013893859460949898
# Loss in episode 0 is 0.00376448524184525
# Loss in episode 0 is 0.009990954771637917
# Loss in episode 0 is 0.008385694585740566
# Loss in episode 0 is 0.005515183787792921
# Loss in episode 0 is 0.00013974460307508707
# Loss in episode 0 is 0.015904057770967484
# Loss in episode 0 is 0.0015389396576210856
# Loss in episode 0 is 0.006316233891993761
# Loss in episode 0 is 0.006508302874863148
# Loss in episode 0 is 0.005640496499836445
# Loss in episode 0 is 0.00034117919858545065
# Loss in episode 0 is 0.004071825183928013
# Loss in episode 0 is 0.012234684079885483
# Loss in episode 0 is 0.041189536452293396
# Loss in episode 0 is 0.004503183998167515
# Loss in episode 0 is 0.004355971235781908
# Loss in episode 0 is 0.0016633798368275166
# Loss in episode 0 is 0.0192495658993721
# Loss in episode 0 is 0.0006436395342461765
# Loss in episode 0 is 0.007477153558284044
# Loss in episode 0 is 0.0013606060529127717
# Loss in episode 0 is 0.01342293806374073
# Loss in episode 0 is 0.00012910054647363722
# Loss in episode 0 is 0.015271633863449097
# Loss in episode 0 is 4.3254120100755244e-05
# Loss in episode 0 is 0.003531696042045951
# Loss in episode 0 is 8.484520367346704e-05
# Loss in episode 0 is 0.005826173350214958
# Loss in episode 0 is 0.0002382654492976144
# Loss in episode 0 is 0.007585020735859871
# Loss in episode 0 is 0.004405109211802483
# Loss in episode 0 is 0.002018890343606472
# Loss in episode 0 is 0.00941658765077591
# Loss in episode 0 is 0.0029314097482711077
# Loss in episode 0 is 0.0008904646383598447
# Loss in episode 0 is 0.0005266251391731203
# Loss in episode 0 is 0.0020825781393796206
# Loss in episode 0 is 0.006903792265802622
# Loss in episode 0 is 0.02446921542286873
# Loss in episode 0 is 0.003766976296901703
# Loss in episode 0 is 1.1644105143204797e-05
# Loss in episode 0 is 0.00032553914934396744
# Loss in episode 0 is 0.0015791093464940786
# Loss in episode 0 is 0.002332311123609543
# Loss in episode 0 is 0.001657717628404498
# Loss in episode 0 is 0.0002768140402622521
# Loss in episode 0 is 1.238335607922636e-05
# Loss in episode 0 is 0.0006852063816040754
# Loss in episode 0 is 0.0002760070201475173
# Loss in episode 0 is 0.0010860213078558445
# Loss in episode 0 is 0.0010517282644286752
# Loss in episode 0 is 0.006103739142417908
# Loss in episode 0 is 0.0012826540041714907
# Loss in episode 0 is 0.0029977632220834494
# Loss in episode 0 is 0.0057448092848062515
# Loss in episode 0 is 0.028577277436852455
# Loss in episode 0 is 0.001945671159774065
# Loss in episode 0 is 8.89475631993264e-06
# Loss in episode 0 is 0.0056138187646865845
# Loss in episode 0 is 1.1610282854235265e-05
# Loss in episode 0 is 0.01066228374838829
# Loss in episode 0 is 4.4526782971843204e-07
# Loss in episode 0 is 0.009906240738928318
# Loss in episode 0 is 0.002381235593929887
# Loss in episode 0 is 0.0034831527154892683
# Loss in episode 0 is 0.0029574804939329624
# Loss in episode 0 is 0.0015995781868696213
# Loss in episode 0 is 0.00022008598898537457
# Loss in episode 0 is 0.0009018511627800763
# Loss in episode 0 is 0.0002752490108832717
# Loss in episode 0 is 0.00011348385305609554
# Loss in episode 0 is 2.404797214694554e-06
# Loss in episode 0 is 0.0004169141175225377
# Loss in episode 0 is 1.0191179171670228e-05
# Loss in episode 0 is 0.0024909900967031717
# Loss in episode 0 is 0.0006063709734007716
# Loss in episode 0 is 5.446830982691608e-06
# Loss in episode 0 is 0.0004346960922703147
# Loss in episode 0 is 0.0003124440263491124
# Loss in episode 0 is 0.0003169108531437814
# Loss in episode 0 is 0.005447824951261282
# Loss in episode 0 is 0.01978088915348053
# Loss in episode 0 is 0.006693022325634956
# Loss in episode 0 is 0.005658137612044811
# Loss in episode 0 is 0.0012087103677913547
# Loss in episode 0 is 0.0005150242359377444
# Loss in episode 0 is 0.007024290040135384
# Loss in episode 0 is 0.0005501791602000594
# Loss in episode 0 is 0.005119087174534798
# Loss in episode 0 is 0.0019569233991205692
# Loss in episode 0 is 0.0007425904623232782
# Loss in episode 0 is 8.739030454307795e-05
# Loss in episode 0 is 0.003042292082682252
# Loss in episode 0 is 0.0007543800165876746
# Loss in episode 0 is 0.0002021049876930192
# Loss in episode 0 is 0.022220125421881676
# Loss in episode 0 is 0.000954234681557864
# Loss in episode 0 is 0.009050882421433926
# Loss in episode 0 is 0.00013284554006531835
# Loss in episode 0 is 7.277625263668597e-05
# Loss in episode 0 is 0.0013441520277410746
# Loss in episode 0 is 0.0030278884805738926
# Loss in episode 0 is 0.00011043280392186716
# Loss in episode 0 is 2.3725571736576967e-05
# Loss in episode 0 is 0.00013822474284097552
# Loss in episode 0 is 0.00442739762365818
# Loss in episode 0 is 0.003535984316840768
# Loss in episode 0 is 0.0032397271133959293
# Loss in episode 0 is 0.00013251931522972882
# Loss in episode 0 is 2.4332437078555813e-06
# Loss in episode 0 is 0.0007711066864430904
# Loss in episode 0 is 6.803533324273303e-05
# Loss in episode 0 is 0.0008299823966808617
# Loss in episode 0 is 0.002987501909956336
# Loss in episode 0 is 0.00014064293645787984
# Loss in episode 0 is 0.0007518163183704019
# Loss in episode 0 is 0.0010744794271886349
# Loss in episode 0 is 0.0004302750458009541
# Loss in episode 0 is 9.645970567362383e-05
# Loss in episode 0 is 0.003406350500881672
# Loss in episode 0 is 0.0006503274780698121
# Loss in episode 0 is 0.00010219255636911839
# Loss in episode 0 is 0.0011931651970371604
# Loss in episode 0 is 4.801620889338665e-05
# Loss in episode 0 is 4.311891825636849e-05
# Loss in episode 0 is 0.0011101624695584178
# Loss in episode 0 is 0.0008483993005938828
# Loss in episode 0 is 0.0023793226573616266
# Loss in episode 0 is 4.15539980167523e-05
# Loss in episode 0 is 0.010797242633998394
# Loss in episode 0 is 0.0006030192598700523
# Loss in episode 0 is 0.00021004138397984207
# Loss in episode 0 is 0.0037121810019016266
# Loss in episode 0 is 0.0032310604583472013
# Loss in episode 0 is 0.00021726131672039628
# Loss in episode 0 is 0.00036571468808688223
# Loss in episode 0 is 0.0019555494654923677
# Loss in episode 0 is 0.011694541200995445
# Loss in episode 0 is 0.00024009979097172618
# Loss in episode 0 is 0.0019357316195964813
# Loss in episode 0 is 0.0002793871390167624
# Loss in episode 0 is 0.0003648120036814362
# Loss in episode 0 is 0.0011986879399046302
# Loss in episode 0 is 0.00054954644292593
# Loss in episode 0 is 0.0004903897061012685
# Loss in episode 0 is 0.000113922287710011
# Loss in episode 0 is 0.0004400979960337281
# Loss in episode 0 is 2.4649671104270965e-05
# Loss in episode 0 is 0.0016282519791275263
# Loss in episode 0 is 0.009273316711187363
# Loss in episode 0 is 6.612054221477592e-06
# Loss in episode 0 is 0.0005413817707449198
# Loss in episode 0 is 0.01557220984250307
# Loss in episode 0 is 0.0014407464768737555
# Loss in episode 0 is 0.002460233401507139
# Loss in episode 0 is 0.0003726313298102468
# Loss in episode 0 is 0.00043190756696276367
# Loss in episode 0 is 0.0003409852215554565
# Loss in episode 0 is 0.0010301665170118213
# Loss in episode 0 is 3.307398856122745e-06
# Loss in episode 0 is 0.003988714423030615
# Loss in episode 0 is 0.00016806570056360215
# Loss in episode 0 is 0.0030748085118830204
# Loss in episode 0 is 0.004525779280811548
# Loss in episode 0 is 0.00039668139652349055
# Loss in episode 0 is 5.022816185373813e-05
# Loss in episode 0 is 0.00031140531064011157
# Loss in episode 0 is 0.002394522074609995
# Loss in episode 0 is 9.625843085814267e-05
# Loss in episode 0 is 0.00276776310056448
# Loss in episode 0 is 0.0003299140662420541
# Loss in episode 0 is 1.5629781557890965e-07
# Loss in episode 0 is 4.073294985573739e-05
# Loss in episode 0 is 6.317791121546179e-05
# Loss in episode 0 is 0.00013738131383433938
# Loss in episode 0 is 0.010258381254971027
# Loss in episode 0 is 0.001480181235820055
# Loss in episode 0 is 0.007938859984278679
# Loss in episode 0 is 0.0020652899984270334
# Loss in episode 0 is 0.00438632071018219
# Loss in episode 0 is 0.00027208475512452424
# Loss in episode 0 is 8.350203279405832e-05
# Loss in episode 0 is 0.00016081688227131963
# Loss in episode 0 is 0.0020074390340596437
# Loss in episode 0 is 0.00017774671141523868
# Loss in episode 0 is 0.0046036094427108765
# Loss in episode 0 is 0.006140515673905611
# Loss in episode 0 is 0.0033997551072388887
# Loss in episode 0 is 0.0005495601799339056
# Loss in episode 0 is 9.94400124909589e-06
# Loss in episode 0 is 0.00022886334045324475
# Loss in episode 0 is 0.00011470092431409284
# Loss in episode 0 is 0.0019388203509151936
# Loss in episode 0 is 2.7815682187792845e-05
# Loss in episode 0 is 0.0006591691053472459
# Loss in episode 0 is 0.0006024711183272302
# Loss in episode 0 is 0.003801478771492839
# Loss in episode 0 is 0.0006153722642920911
# Loss in episode 0 is 0.0006579206674359739
# Loss in episode 0 is 0.002798113040626049
# Loss in episode 0 is 0.00024977276916615665
# Loss in episode 0 is 0.0004960066289640963
# Loss in episode 0 is 0.0002543091541156173
# Loss in episode 0 is 9.702123497845605e-05
# Loss in episode 0 is 0.0014568469487130642
# Loss in episode 0 is 9.623153164284304e-05
# Loss in episode 0 is 0.00027090139337815344
# Loss in episode 0 is 0.006287336815148592
# Loss in episode 0 is 0.0009785426082089543
# Loss in episode 0 is 9.756035433383659e-05
# Loss in episode 0 is 0.0038176486268639565
# Loss in episode 0 is 0.00015165162039920688
# Loss in episode 0 is 0.0007909450796432793
# Loss in episode 0 is 0.002578361891210079
# Loss in episode 0 is 4.1303326725028455e-05
# Loss in episode 0 is 0.00044621393317356706
# Loss in episode 0 is 0.00039874762296676636
# Loss in episode 0 is 8.767648250795901e-05
# Loss in episode 0 is 0.0007940090144984424
# Loss in episode 0 is 6.674718315480277e-05
# Loss in episode 0 is 0.0005690084653906524
# Loss in episode 0 is 0.0034428653307259083
# Loss in episode 0 is 0.00013882992789149284
# Loss in episode 0 is 6.545106771227438e-06
# Loss in episode 0 is 0.0031854843255132437
# Loss in episode 0 is 0.00106515409424901
# Loss in episode 0 is 0.004399328958243132
# Loss in episode 0 is 0.004142597317695618
# Loss in episode 0 is 0.00012339944078121334
# Loss in episode 0 is 0.00197746348567307
# Loss in episode 0 is 0.004671095870435238
# Loss in episode 0 is 0.0022248011082410812
# Loss in episode 0 is 0.0879080519080162
# Loss in episode 0 is 0.00041399328620173037
# Loss in episode 0 is 0.0003472645184956491
# Loss in episode 0 is 1.526586311229039e-05
# Loss in episode 0 is 2.1213218133198097e-06
# Loss in episode 0 is 0.001109961187466979
# Loss in episode 0 is 0.0040576704777777195
# Loss in episode 0 is 0.000400989199988544
# Loss in episode 0 is 0.004916732665151358
# Loss in episode 0 is 0.0003355630615260452
# Loss in episode 0 is 1.9762084775720723e-05
# Loss in episode 0 is 0.0007974751642905176
# Loss in episode 0 is 0.0004543336108326912
# Loss in episode 0 is 0.005731781478971243
# Loss in episode 0 is 0.001024769153445959
# Loss in episode 0 is 0.006917198188602924
# Loss in episode 0 is 0.007266936358064413
# Loss in episode 0 is 0.00022355426335707307
# Loss in episode 0 is 0.0003506620123516768
# Loss in episode 0 is 0.0006517076399177313
# Loss in episode 0 is 0.00016951927682384849
# Loss in episode 0 is 0.0001119204971473664
# Loss in episode 0 is 0.002212334657087922
# Loss in episode 0 is 8.451459143543616e-05
# Loss in episode 0 is 0.001206601969897747
# Loss in episode 0 is 0.00012577998859342188
# Loss in episode 0 is 0.00010154908522963524
# Loss in episode 0 is 1.0315092367818579e-05
# Loss in episode 0 is 0.003558439901098609
# Loss in episode 0 is 1.0346895578550175e-05
# Loss in episode 0 is 0.00010453438153490424
# Loss in episode 0 is 0.001204056665301323
# Loss in episode 0 is 0.0015175874577835202
# Loss in episode 0 is 0.003055616281926632
# Loss in episode 0 is 0.007857037708163261
# Loss in episode 0 is 6.942394975339994e-05
# Loss in episode 0 is 9.760547072801273e-06
# Loss in episode 0 is 0.0017803683876991272
# Loss in episode 0 is 1.5562322005280294e-05
# Loss in episode 0 is 0.0005597339477390051
# Loss in episode 0 is 0.00047812971752136946
# Loss in episode 0 is 0.00039578916039317846
# Loss in episode 0 is 0.00019765456090681255
# Loss in episode 0 is 5.2930539823137224e-05
# Loss in episode 0 is 0.00029124648426659405
# Loss in episode 0 is 0.0001786601496860385
# Loss in episode 0 is 0.0005610368098132312
# Loss in episode 0 is 0.00039061729330569506
# Loss in episode 0 is 3.87729733120068e-06
# Loss in episode 0 is 2.4438437321805395e-05
# Loss in episode 0 is 3.6648500099545345e-05
# Loss in episode 0 is 9.396862878929824e-05
# Loss in episode 0 is 0.0014024389674887061
# Loss in episode 0 is 0.0004867589450441301
# Loss in episode 0 is 0.0010832929983735085
# Loss in episode 1 is 4.9479516746941954e-05
# Loss in episode 1 is 2.8462456612032838e-05
# Loss in episode 1 is 6.701055099256337e-06
# Loss in episode 1 is 0.0006038395222276449
# Loss in episode 1 is 0.0002140813012374565
# Loss in episode 1 is 7.624402087458293e-07
# Loss in episode 1 is 0.0004291502700652927
# Loss in episode 1 is 0.0018247850239276886
# Loss in episode 1 is 4.4573531340574846e-05
# Loss in episode 1 is 0.0002344795793760568
# Loss in episode 1 is 0.00016378120926674455
# Loss in episode 1 is 0.0004079125646967441
# Loss in episode 1 is 0.0003887858474627137
# Loss in episode 1 is 0.0007358714356087148
# Loss in episode 1 is 0.0014268800150603056
# Loss in episode 1 is 0.0008370982832275331
# Loss in episode 1 is 0.003008623141795397
# Loss in episode 1 is 6.058028156985529e-05
# Loss in episode 1 is 0.0017120691481977701
# Loss in episode 1 is 0.00015591696137562394
# Loss in episode 1 is 5.272937778499909e-05
# Loss in episode 1 is 2.325298555660993e-05
# Loss in episode 1 is 0.0012888850178569555
# Loss in episode 1 is 0.0004051164723932743
# Loss in episode 1 is 7.139195190575265e-08
# Loss in episode 1 is 0.00014125165762379766
# Loss in episode 1 is 0.00021203856158535928
# Loss in episode 1 is 3.9954952626430895e-06
# Loss in episode 1 is 0.0006172070861794055
# Loss in episode 1 is 4.864738457399653e-06
# Loss in episode 1 is 4.974786133971065e-05
# Loss in episode 1 is 5.3500749345403165e-05
# Loss in episode 1 is 6.40300459053833e-06
# Loss in episode 1 is 0.000439790659584105
# Loss in episode 1 is 0.0001964447001228109
# Loss in episode 1 is 0.00044648131006397307
# Loss in episode 1 is 2.668549495865591e-05
# Loss in episode 1 is 0.009010096080601215
# Loss in episode 1 is 3.796152304857969e-05
# Loss in episode 1 is 3.883774115820415e-05
# Loss in episode 1 is 0.0016030636616051197
# Loss in episode 1 is 0.00020553669310174882
# Loss in episode 1 is 1.8554930036884798e-08
# Loss in episode 1 is 0.003154465928673744
# Loss in episode 1 is 0.0004185827274341136
# Loss in episode 1 is 0.001219860278069973
# Loss in episode 1 is 0.0021843193098902702
# Loss in episode 1 is 0.0002852165198419243
# Loss in episode 1 is 0.0005174318794161081
# Loss in episode 1 is 9.51217589317821e-06
# Loss in episode 1 is 0.00013215561921242625
# Loss in episode 1 is 0.00037335685919970274
# Loss in episode 1 is 0.00022853734844829887
# Loss in episode 1 is 0.00013724576274398714
# Loss in episode 1 is 1.771857205312699e-05
# Loss in episode 1 is 0.0014419450890272856
# Loss in episode 1 is 0.0007224978762678802
# Loss in episode 1 is 0.0008192288805730641
# Loss in episode 1 is 3.1692918128101155e-05
# Loss in episode 1 is 0.0001986876013688743
# Loss in episode 1 is 0.002868517069146037
# Loss in episode 1 is 9.00889135664329e-05
# Loss in episode 1 is 1.3441165719996206e-05
# Loss in episode 1 is 0.0004730281652882695
# Loss in episode 1 is 4.0955863369163126e-05
# Loss in episode 1 is 0.0018180416664108634
# Loss in episode 1 is 0.00014109694166108966
# Loss in episode 1 is 0.0010447524255141616
# Loss in episode 1 is 0.00011836301564471796
# Loss in episode 1 is 1.6803402104415e-05
# Loss in episode 1 is 5.9761994634754956e-05
# Loss in episode 1 is 7.342336903093383e-05
# Loss in episode 1 is 0.00010090665455209091
# Loss in episode 1 is 7.194734644144773e-05
# Loss in episode 1 is 5.031357432017103e-05
# Loss in episode 1 is 0.0014405455440282822
# Loss in episode 1 is 0.00011049380555050448
# Loss in episode 1 is 0.00012013189552817494
# Loss in episode 1 is 0.0009858087869361043
# Loss in episode 1 is 0.004452016204595566
# Loss in episode 1 is 0.00010950655268970877
# Loss in episode 1 is 0.00023970060283318162
# Loss in episode 1 is 2.3268362383532804e-06
# Loss in episode 1 is 7.960240327520296e-05
# Loss in episode 1 is 0.0005699550383724272
# Loss in episode 1 is 0.0007088957936502993
# Loss in episode 1 is 0.0024398169480264187
# Loss in episode 1 is 0.0007294279057532549
# Loss in episode 1 is 3.7481535400729626e-05
# Loss in episode 1 is 8.24289454612881e-05
# Loss in episode 1 is 2.5515830202493817e-05
# Loss in episode 1 is 0.0014657729770988226
# Loss in episode 1 is 0.0017579274717718363
# Loss in episode 1 is 0.0008874709601514041
# Loss in episode 1 is 0.00015904713654890656
# Loss in episode 1 is 3.624482189934497e-07
# Loss in episode 1 is 0.0004492804000619799
# Loss in episode 1 is 0.0002616110723465681
# Loss in episode 1 is 3.924250268028118e-05
# Loss in episode 1 is 0.00022613213513977826
# Loss in episode 1 is 0.004397371783852577
# Loss in episode 1 is 6.120656325947493e-05
# Loss in episode 1 is 0.0014325216179713607
# Loss in episode 1 is 0.0006366416346281767
# Loss in episode 1 is 4.615297802956775e-05
# Loss in episode 1 is 0.0014327361714094877
# Loss in episode 1 is 0.001415592385455966
# Loss in episode 1 is 0.00036251568235456944
# Loss in episode 1 is 9.788793977349997e-05
# Loss in episode 1 is 1.891011379484553e-05
# Loss in episode 1 is 0.0004140496894251555
# Loss in episode 1 is 0.0006903421599417925
# Loss in episode 1 is 0.0003092238330282271
# Loss in episode 1 is 2.3923370463307947e-05
# Loss in episode 1 is 9.487986062595155e-06
# Loss in episode 1 is 7.3033690568991e-05
# Loss in episode 1 is 5.625896665151231e-05
# Loss in episode 1 is 4.806913693755632e-06
# Loss in episode 1 is 0.0004006460076197982
# Loss in episode 1 is 0.000622923078481108
# Loss in episode 1 is 0.00013058212061878294
# Loss in episode 1 is 0.00047891767462715507
# Loss in episode 1 is 0.0009086218778975308
# Loss in episode 1 is 3.524434077917249e-08
# Loss in episode 1 is 0.0013160903472453356
# Loss in episode 1 is 7.684998854529113e-05
# Loss in episode 1 is 1.2030744983348995e-05
# Loss in episode 1 is 0.00011909138993360102
# Loss in episode 1 is 3.4177355701103806e-05
# Loss in episode 1 is 3.861710138153285e-05
# Loss in episode 1 is 0.001073170336894691
# Loss in episode 1 is 0.00012632163998205215
# Loss in episode 1 is 0.0008840886875987053
# Loss in episode 1 is 0.0004962747916579247
# Loss in episode 1 is 0.00010060989734483883
# Loss in episode 1 is 7.89471305324696e-05
# Loss in episode 1 is 2.3064820197760127e-05
# Loss in episode 1 is 0.0011627190979197621
# Loss in episode 1 is 0.0009862221777439117
# Loss in episode 1 is 2.6732574042398483e-05
# Loss in episode 1 is 0.00022274212096817791
# Loss in episode 1 is 0.0003310478350613266
# Loss in episode 1 is 0.001479501137509942
# Loss in episode 1 is 9.747613512445241e-05
# Loss in episode 1 is 0.0003480534069240093
# Loss in episode 1 is 0.0002551005454733968
# Loss in episode 1 is 0.00022237520897760987
# Loss in episode 1 is 0.0007810627575963736
# Loss in episode 1 is 4.9339265387970954e-05
# Loss in episode 1 is 0.0004475960158742964
# Loss in episode 1 is 0.00019588634313549846
# Loss in episode 1 is 4.574544436763972e-05
# Loss in episode 1 is 1.0438808203616645e-05
# Loss in episode 1 is 0.0010685379384085536
# Loss in episode 1 is 0.0011007431894540787
# Loss in episode 1 is 6.675878125861345e-07
# Loss in episode 1 is 1.8500453734304756e-05
# Loss in episode 1 is 0.009259880520403385
# Loss in episode 1 is 9.789199248189107e-05
# Loss in episode 1 is 0.0010835411958396435
# Loss in episode 1 is 5.486603549798019e-05
# Loss in episode 1 is 5.3167357691563666e-05
# Loss in episode 1 is 0.00013002923515159637
# Loss in episode 1 is 0.00027920553111471236
# Loss in episode 1 is 5.525465167011134e-05
# Loss in episode 1 is 0.0012020283611491323
# Loss in episode 1 is 0.00020103376300539821
# Loss in episode 1 is 0.0009506116039119661
# Loss in episode 1 is 4.039262421429157e-05
# Loss in episode 1 is 4.9998314352706075e-05
# Loss in episode 1 is 4.112506576348096e-05
# Loss in episode 1 is 1.1327872925903648e-05
# Loss in episode 1 is 0.0006856170948594809
# Loss in episode 1 is 0.00023344813962467015
# Loss in episode 1 is 0.0009418849949724972
# Loss in episode 1 is 3.984827708336525e-05
# Loss in episode 1 is 1.0038469554274343e-05
# Loss in episode 1 is 6.805599696235731e-05
# Loss in episode 1 is 7.097145862644538e-05
# Loss in episode 1 is 3.7782200479341554e-07
# Loss in episode 1 is 0.006361810490489006
# Loss in episode 1 is 0.00012549926759675145
# Loss in episode 1 is 0.00041781755862757564
# Loss in episode 1 is 0.000267553492449224
# Loss in episode 1 is 0.0023022014647722244
# Loss in episode 1 is 3.578951509553008e-05
# Loss in episode 1 is 5.146105831954628e-05
# Loss in episode 1 is 1.8950049707200378e-05
# Loss in episode 1 is 0.0006184278754517436
# Loss in episode 1 is 0.00022518901096191257
# Loss in episode 1 is 0.0002455793146509677
# Loss in episode 1 is 0.004027459304779768
# Loss in episode 1 is 0.0016087648691609502
# Loss in episode 1 is 0.0004336755082476884
# Loss in episode 1 is 1.8170740077039227e-06
# Loss in episode 1 is 3.4084703656844795e-05
# Loss in episode 1 is 2.760655479505658e-05
# Loss in episode 1 is 0.0008843683754093945
# Loss in episode 1 is 8.981615246739239e-05
# Loss in episode 1 is 0.0002020062820520252
# Loss in episode 1 is 3.088954827035195e-06
# Loss in episode 1 is 0.0010283737210556865
# Loss in episode 1 is 0.00022358137357514352
# Loss in episode 1 is 0.00013845339708495885
# Loss in episode 1 is 0.001150584314018488
# Loss in episode 1 is 4.390723188407719e-05
# Loss in episode 1 is 3.7203503211458155e-07
# Loss in episode 1 is 4.603690467774868e-05
# Loss in episode 1 is 2.058248719549738e-05
# Loss in episode 1 is 0.0006685195257887244
# Loss in episode 1 is 6.771872722310945e-05
# Loss in episode 1 is 6.953623233130202e-05
# Loss in episode 1 is 0.00036485923919826746
# Loss in episode 1 is 0.00016702915308997035
# Loss in episode 1 is 1.7765949451131746e-05
# Loss in episode 1 is 0.0012176265008747578
# Loss in episode 1 is 4.5975968532729894e-05
# Loss in episode 1 is 0.00013618642697110772
# Loss in episode 1 is 0.00039145315531641245
# Loss in episode 1 is 6.201281939866021e-05
# Loss in episode 1 is 0.00015787447046022862
# Loss in episode 1 is 9.475925617152825e-05
# Loss in episode 1 is 6.183379446156323e-05
# Loss in episode 1 is 0.000655175419524312
# Loss in episode 1 is 2.361493170610629e-05
# Loss in episode 1 is 0.0010825577192008495
# Loss in episode 1 is 0.0018448223127052188
# Loss in episode 1 is 9.658025845737939e-08
# Loss in episode 1 is 0.0001623005955480039
# Loss in episode 1 is 0.0009232788579538465
# Loss in episode 1 is 0.0004219454131089151
# Loss in episode 1 is 0.0015568867092952132
# Loss in episode 1 is 0.0020089170429855585
# Loss in episode 1 is 0.00014860174269415438
# Loss in episode 1 is 0.002037109574303031
# Loss in episode 1 is 0.0029682691674679518
# Loss in episode 1 is 5.500845418282552e-06
# Loss in episode 1 is 0.07496555894613266
# Loss in episode 1 is 0.00012232462177053094
# Loss in episode 1 is 9.423059964319691e-05
# Loss in episode 1 is 2.0469590253924252e-06
# Loss in episode 1 is 5.5786007578717545e-05
# Loss in episode 1 is 0.00031765588209964335
# Loss in episode 1 is 0.0005690027610398829
# Loss in episode 1 is 0.0001908294652821496
# Loss in episode 1 is 0.0027511906810104847
# Loss in episode 1 is 9.230947034666315e-05
# Loss in episode 1 is 8.176325394515516e-09
# Loss in episode 1 is 0.0002174021938117221
# Loss in episode 1 is 0.00010601573740132153
# Loss in episode 1 is 0.0022683492861688137
# Loss in episode 1 is 0.0002729480038397014
# Loss in episode 1 is 0.002523913746699691
# Loss in episode 1 is 0.0034441016614437103
# Loss in episode 1 is 4.884275040240027e-05
# Loss in episode 1 is 9.737616346683353e-05
# Loss in episode 1 is 0.00019476488523650914
# Loss in episode 1 is 0.00021649646805599332
# Loss in episode 1 is 1.1195956176379696e-05
# Loss in episode 1 is 8.274203082692111e-07
# Loss in episode 1 is 9.856060933088884e-05
# Loss in episode 1 is 0.0006774080102331936
# Loss in episode 1 is 1.740866900945548e-05
# Loss in episode 1 is 6.217049667611718e-05
# Loss in episode 1 is 4.265649113222025e-05
# Loss in episode 1 is 0.0008655927376821637
# Loss in episode 1 is 3.008831299666781e-05
# Loss in episode 1 is 0.00024989218218252063
# Loss in episode 1 is 0.00040463331970386207
# Loss in episode 1 is 0.0008515274967066944
# Loss in episode 1 is 0.0011289851972833276
# Loss in episode 1 is 0.006718499585986137
# Loss in episode 1 is 6.209844286786392e-06
# Loss in episode 1 is 3.806607855949551e-05
# Loss in episode 1 is 0.0007790595409460366
# Loss in episode 1 is 8.460993740300182e-06
# Loss in episode 1 is 0.00020843428501393646
# Loss in episode 1 is 0.0002682252961676568
# Loss in episode 1 is 1.040654387907125e-05
# Loss in episode 1 is 0.00019878199964296073
# Loss in episode 1 is 4.060163519170601e-06
# Loss in episode 1 is 7.451316923834383e-05
# Loss in episode 1 is 3.996619489043951e-05
# Loss in episode 1 is 0.0005916748777963221
# Loss in episode 1 is 0.00024020193086471409
# Loss in episode 1 is 8.010562737581495e-07
# Loss in episode 1 is 0.00010055450547952205
# Loss in episode 1 is 2.1921281586401165e-05
# Loss in episode 1 is 0.00013158675574231893
# Loss in episode 1 is 0.000398427015170455
# Loss in episode 1 is 0.00010447152453707531
# Loss in episode 1 is 0.0002851831668522209
# Loss in episode 2 is 6.302774636424147e-06
# Loss in episode 2 is 1.8558994270279072e-05
# Loss in episode 2 is 7.358690345427021e-05
# Loss in episode 2 is 0.00023497449001297355
# Loss in episode 2 is 8.264135249191895e-05
# Loss in episode 2 is 4.523622578744835e-07
# Loss in episode 2 is 0.00010198696691077203
# Loss in episode 2 is 0.001180918188765645
# Loss in episode 2 is 8.217287359002512e-06
# Loss in episode 2 is 5.5546057410538197e-05
# Loss in episode 2 is 7.218170503620058e-05
# Loss in episode 2 is 0.0003392256039660424
# Loss in episode 2 is 0.00016011772095225751
# Loss in episode 2 is 0.0005586667684838176
# Loss in episode 2 is 0.0007746697519905865
# Loss in episode 2 is 0.0003337295784149319
# Loss in episode 2 is 0.0009103622287511826
# Loss in episode 2 is 3.881694283336401e-05
# Loss in episode 2 is 7.502786502300296e-06
# Loss in episode 2 is 0.00018344231648370624
# Loss in episode 2 is 1.3834633136866614e-05
# Loss in episode 2 is 2.1061576262582093e-05
# Loss in episode 2 is 0.0006456883857026696
# Loss in episode 2 is 0.0002831610618159175
# Loss in episode 2 is 4.734485798962851e-07
# Loss in episode 2 is 7.34770146664232e-05
# Loss in episode 2 is 5.5999462347244844e-05
# Loss in episode 2 is 9.52212849369971e-06
# Loss in episode 2 is 0.00015037640696391463
# Loss in episode 2 is 2.0938299712724984e-05
# Loss in episode 2 is 1.3077540643280372e-05
# Loss in episode 2 is 4.882366192759946e-05
# Loss in episode 2 is 4.51646264991723e-05
# Loss in episode 2 is 0.00015598730533383787
# Loss in episode 2 is 0.00010186590952798724
# Loss in episode 2 is 0.0002787905978038907
# Loss in episode 2 is 8.500829835611512e-07
# Loss in episode 2 is 0.005393991246819496
# Loss in episode 2 is 1.0056513019662816e-05
# Loss in episode 2 is 5.778717604698613e-05
# Loss in episode 2 is 0.0005384564865380526
# Loss in episode 2 is 0.0001436276943422854
# Loss in episode 2 is 2.2978165361564606e-05
# Loss in episode 2 is 0.0006285214331001043
# Loss in episode 2 is 1.753290598571766e-05
# Loss in episode 2 is 0.0008610954973846674
# Loss in episode 2 is 0.00042746891267597675
# Loss in episode 2 is 0.000398981967009604
# Loss in episode 2 is 5.550441346713342e-05
# Loss in episode 2 is 9.545536886435002e-05
# Loss in episode 2 is 4.4467378756962717e-05
# Loss in episode 2 is 0.0006227075355127454
# Loss in episode 2 is 0.0001865246013039723
# Loss in episode 2 is 9.096555913856719e-06
# Loss in episode 2 is 1.5792389604030177e-05
# Loss in episode 2 is 0.0004993999027647078
# Loss in episode 2 is 0.00024044040765147656
# Loss in episode 2 is 0.0011755004525184631
# Loss in episode 2 is 3.182850559824146e-05
# Loss in episode 2 is 8.838586654746905e-05
# Loss in episode 2 is 0.0004138421209063381
# Loss in episode 2 is 2.579468855401501e-05
# Loss in episode 2 is 7.055934474919923e-06
# Loss in episode 2 is 0.00019976742623839527
# Loss in episode 2 is 3.778867707637801e-08
# Loss in episode 2 is 0.0007971583399921656
# Loss in episode 2 is 6.687124596282956e-07
# Loss in episode 2 is 0.00043398162233643234
# Loss in episode 2 is 6.065050547476858e-05
# Loss in episode 2 is 1.2991284847885254e-07
# Loss in episode 2 is 1.1857175195473246e-05
# Loss in episode 2 is 1.764739863574505e-05
# Loss in episode 2 is 0.0001149485251517035
# Loss in episode 2 is 4.6249064325820655e-05
# Loss in episode 2 is 1.9663390048663132e-05
# Loss in episode 2 is 0.0006433248054236174
# Loss in episode 2 is 4.6680899686180055e-05
# Loss in episode 2 is 2.558316737122368e-05
# Loss in episode 2 is 0.0009387761820107698
# Loss in episode 2 is 0.00351845845580101
# Loss in episode 2 is 2.5017181542352773e-05
# Loss in episode 2 is 5.330137719283812e-05
# Loss in episode 2 is 4.599141902872361e-05
# Loss in episode 2 is 3.791607014136389e-05
# Loss in episode 2 is 0.00011991433711955324
# Loss in episode 2 is 0.00014336280582938343
# Loss in episode 2 is 0.0003035461704712361
# Loss in episode 2 is 0.00013251090422272682
# Loss in episode 2 is 0.0003487121139187366
# Loss in episode 2 is 2.0147192117292434e-05
# Loss in episode 2 is 6.086292614781996e-06
# Loss in episode 2 is 0.0006240859511308372
# Loss in episode 2 is 0.0020299653988331556
# Loss in episode 2 is 0.00043144647497683764
# Loss in episode 2 is 7.790928066242486e-05
# Loss in episode 2 is 5.5408063417417e-06
# Loss in episode 2 is 0.00028665337595157325
# Loss in episode 2 is 0.0001279754505958408
# Loss in episode 2 is 4.1800823964877054e-05
# Loss in episode 2 is 0.00018529078806750476
# Loss in episode 2 is 0.0015070362715050578
# Loss in episode 2 is 1.102258829632774e-05
# Loss in episode 2 is 0.00042500614654272795
# Loss in episode 2 is 0.00031284132273867726
# Loss in episode 2 is 3.710692180902697e-05
# Loss in episode 2 is 0.0005411307793110609
# Loss in episode 2 is 0.0009159672190435231
# Loss in episode 2 is 5.370400322135538e-05
# Loss in episode 2 is 5.982108632451855e-06
# Loss in episode 2 is 7.491960474226289e-08
# Loss in episode 2 is 0.000234115868806839
# Loss in episode 2 is 0.0003434552054386586
# Loss in episode 2 is 3.4765707823680714e-05
# Loss in episode 2 is 5.83693484657033e-08
# Loss in episode 2 is 2.7750131266657263e-05
# Loss in episode 2 is 1.359722409688402e-05
# Loss in episode 2 is 4.323082976043224e-06
# Loss in episode 2 is 6.036868580849841e-05
# Loss in episode 2 is 6.759538518963382e-05
# Loss in episode 2 is 0.000455562025308609
# Loss in episode 2 is 0.0003334224165882915
# Loss in episode 2 is 4.663026629714295e-05
# Loss in episode 2 is 0.00076711067231372
# Loss in episode 2 is 5.21751758242317e-07
# Loss in episode 2 is 0.0008030747412703931
# Loss in episode 2 is 1.4590139471692964e-05
# Loss in episode 2 is 4.5043259888188913e-05
# Loss in episode 2 is 9.493234392721206e-05
# Loss in episode 2 is 2.7680513881023217e-07
# Loss in episode 2 is 3.516155993565917e-05
# Loss in episode 2 is 0.0006996339652687311
# Loss in episode 2 is 7.480059025510855e-07
# Loss in episode 2 is 0.0003277243231423199
# Loss in episode 2 is 0.00042894622310996056
# Loss in episode 2 is 9.221253276336938e-05
# Loss in episode 2 is 1.3577157005784102e-05
# Loss in episode 2 is 4.035759047837928e-06
# Loss in episode 2 is 0.0004178578674327582
# Loss in episode 2 is 0.0004739973519463092
# Loss in episode 2 is 5.506322395376628e-06
# Loss in episode 2 is 0.00024720351211726665
# Loss in episode 2 is 5.151033110450953e-05
# Loss in episode 2 is 0.00015090155648067594
# Loss in episode 2 is 3.8135458453325555e-05
# Loss in episode 2 is 6.212860171217471e-05
# Loss in episode 2 is 0.00027019146364182234
# Loss in episode 2 is 0.00012767930456902832
# Loss in episode 2 is 0.0005191854434087873
# Loss in episode 2 is 0.00030603024060837924
# Loss in episode 2 is 0.0004144698614254594
# Loss in episode 2 is 0.00012978473387192935
# Loss in episode 2 is 4.4717598939314485e-06
# Loss in episode 2 is 2.5521250790916383e-05
# Loss in episode 2 is 0.0005439305678009987
# Loss in episode 2 is 0.00018736108904704452
# Loss in episode 2 is 1.9198304812562128e-07
# Loss in episode 2 is 0.00020009203581139445
# Loss in episode 2 is 0.004877077881246805
# Loss in episode 2 is 0.00016893792781047523
# Loss in episode 2 is 0.0004517531197052449
# Loss in episode 2 is 2.9099135645083152e-05
# Loss in episode 2 is 8.069564501056448e-06
# Loss in episode 2 is 2.2026501028449275e-05
# Loss in episode 2 is 7.203585118986666e-05
# Loss in episode 2 is 6.720734381815419e-05
# Loss in episode 2 is 0.00022237023222260177
# Loss in episode 2 is 4.319338040659204e-05
# Loss in episode 2 is 0.00019704345322679728
# Loss in episode 2 is 0.0003506474895402789
# Loss in episode 2 is 9.078467883227859e-06
# Loss in episode 2 is 1.3127874808560591e-05
# Loss in episode 2 is 6.474700785474852e-05
# Loss in episode 2 is 0.0002555442915763706
# Loss in episode 2 is 0.00019443167548161
# Loss in episode 2 is 0.00022031001572031528
# Loss in episode 2 is 8.599549801147077e-06
# Loss in episode 2 is 5.109091034682933e-06
# Loss in episode 2 is 4.3336742237443104e-05
# Loss in episode 2 is 9.361554839415476e-05
# Loss in episode 2 is 6.780464900657535e-06
# Loss in episode 2 is 0.0034485915675759315
# Loss in episode 2 is 3.6961677096769563e-07
# Loss in episode 2 is 4.107377753825858e-05
# Loss in episode 2 is 3.105111318291165e-05
# Loss in episode 2 is 0.001073939260095358
# Loss in episode 2 is 1.0966261470457539e-05
# Loss in episode 2 is 1.6056754247983918e-05
# Loss in episode 2 is 4.9348160246154293e-05
# Loss in episode 2 is 0.00024216681777033955
# Loss in episode 2 is 0.00014195984113030136
# Loss in episode 2 is 1.040209099301137e-05
# Loss in episode 2 is 0.0022325562313199043
# Loss in episode 2 is 0.0007110537262633443
# Loss in episode 2 is 0.0004296478000469506
# Loss in episode 2 is 9.584567305864766e-05
# Loss in episode 2 is 1.2905028597742785e-05
# Loss in episode 2 is 1.0043821930594277e-05
# Loss in episode 2 is 0.0003180077183060348
# Loss in episode 2 is 9.897298878058791e-05
# Loss in episode 2 is 8.373212767764926e-05
# Loss in episode 2 is 1.000689371721819e-05
# Loss in episode 2 is 0.0001178396341856569
# Loss in episode 2 is 6.71156813041307e-05
# Loss in episode 2 is 3.835583811451215e-06
# Loss in episode 2 is 0.0005524682928808033
# Loss in episode 2 is 5.7911840656288405e-08
# Loss in episode 2 is 3.5258999560028315e-05
# Loss in episode 2 is 1.5057631571835373e-05
# Loss in episode 2 is 5.983648861729307e-06
# Loss in episode 2 is 0.00027467592735774815
# Loss in episode 2 is 3.901810850948095e-05
# Loss in episode 2 is 1.0863372153835371e-05
# Loss in episode 2 is 1.7014079276123084e-05
# Loss in episode 2 is 9.117870831687469e-06
# Loss in episode 2 is 7.228658915892083e-08
# Loss in episode 2 is 0.0002966091560665518
# Loss in episode 2 is 9.929328371072188e-06
# Loss in episode 2 is 7.93588060332695e-06
# Loss in episode 2 is 0.0001962136448128149
# Loss in episode 2 is 4.953627285431139e-05
# Loss in episode 2 is 2.956249772978481e-06
# Loss in episode 2 is 2.7718891942640767e-05
# Loss in episode 2 is 5.569916174863465e-05
# Loss in episode 2 is 0.00045390933519229293
# Loss in episode 2 is 4.476035883271834e-06
# Loss in episode 2 is 0.0010296758264303207
# Loss in episode 2 is 0.0009436424006707966
# Loss in episode 2 is 1.190744478662964e-05
# Loss in episode 2 is 6.454803951783106e-05
# Loss in episode 2 is 0.00021070273942314088
# Loss in episode 2 is 0.00011090388579759747
# Loss in episode 2 is 0.0005244342610239983
# Loss in episode 2 is 0.001062080729752779
# Loss in episode 2 is 0.00015195953892543912
# Loss in episode 2 is 0.0014695203863084316
# Loss in episode 2 is 0.0018451884388923645
# Loss in episode 2 is 2.0562887584674172e-05
# Loss in episode 2 is 0.06474030762910843
# Loss in episode 2 is 4.3914671550737694e-05
# Loss in episode 2 is 1.9922488718293607e-05
# Loss in episode 2 is 4.4467142288340256e-06
# Loss in episode 2 is 0.00011303856445010751
# Loss in episode 2 is 9.33369155973196e-05
# Loss in episode 2 is 8.710988913662732e-05
# Loss in episode 2 is 8.641783642815426e-05
# Loss in episode 2 is 0.001556816278025508
# Loss in episode 2 is 3.12137563014403e-05
# Loss in episode 2 is 1.914626864163438e-06
# Loss in episode 2 is 2.2574944523512386e-05
# Loss in episode 2 is 7.715501124039292e-05
# Loss in episode 2 is 0.0007588667212985456
# Loss in episode 2 is 3.643017407739535e-05
# Loss in episode 2 is 0.0008212533430196345
# Loss in episode 2 is 0.001881657401099801
# Loss in episode 2 is 1.4050554455025122e-05
# Loss in episode 2 is 2.6379037080914713e-05
# Loss in episode 2 is 4.269315832061693e-05
# Loss in episode 2 is 0.0001935383479576558
# Loss in episode 2 is 2.3814327505533583e-06
# Loss in episode 2 is 6.230009603314102e-05
# Loss in episode 2 is 0.00014946391456760466
# Loss in episode 2 is 0.0004180259129498154
# Loss in episode 2 is 3.6596493373508565e-06
# Loss in episode 2 is 5.3642452257918194e-05
# Loss in episode 2 is 5.991414946038276e-05
# Loss in episode 2 is 0.00028288218891248107
# Loss in episode 2 is 3.204530003131367e-05
# Loss in episode 2 is 0.00015904344036243856
# Loss in episode 2 is 0.00013534826575778425
# Loss in episode 2 is 0.0005356803303584456
# Loss in episode 2 is 0.0003788055619224906
# Loss in episode 2 is 0.005851902533322573
# Loss in episode 2 is 1.4187889973982237e-06
# Loss in episode 2 is 4.050034112879075e-05
# Loss in episode 2 is 0.0003115375293418765
# Loss in episode 2 is 1.6266523061858607e-06
# Loss in episode 2 is 6.397577817551792e-05
# Loss in episode 2 is 0.00015931671077851206
# Loss in episode 2 is 1.2083914668892248e-07
# Loss in episode 2 is 0.0001429094118066132
# Loss in episode 2 is 9.996663266065298e-07
# Loss in episode 2 is 1.74861415871419e-05
# Loss in episode 2 is 9.579769539413974e-06
# Loss in episode 2 is 0.000385414925403893
# Loss in episode 2 is 0.0001131065801018849
# Loss in episode 2 is 1.2512525700003607e-06
# Loss in episode 2 is 0.0001051467697834596
# Loss in episode 2 is 2.915766117439489e-07
# Loss in episode 2 is 0.00010309199569746852
# Loss in episode 2 is 0.0002592571545392275
# Loss in episode 2 is 1.5869520211708732e-05
# Loss in episode 2 is 0.000510792073328048
# Loss in episode 3 is 2.9216462280601263e-06
# Loss in episode 3 is 1.9983483070973307e-05
# Loss in episode 3 is 6.615739403059706e-05
# Loss in episode 3 is 7.874437869759277e-05
# Loss in episode 3 is 4.949415597366169e-05
# Loss in episode 3 is 1.411265913020543e-07
# Loss in episode 3 is 9.007995686260983e-06
# Loss in episode 3 is 0.000761213421355933
# Loss in episode 3 is 5.067332949693082e-06
# Loss in episode 3 is 1.1216225175303407e-05
# Loss in episode 3 is 3.8632966607110575e-05
# Loss in episode 3 is 0.0001900431961985305
# Loss in episode 3 is 4.5580571168102324e-05
# Loss in episode 3 is 0.0004610304313246161
# Loss in episode 3 is 0.00046459538862109184
# Loss in episode 3 is 9.068151848623529e-05
# Loss in episode 3 is 0.000239333909121342
# Loss in episode 3 is 6.772522465325892e-05
# Loss in episode 3 is 3.565971564967185e-05
# Loss in episode 3 is 7.204242865554988e-05
# Loss in episode 3 is 8.122336112137418e-06
# Loss in episode 3 is 1.8551818357082084e-06
# Loss in episode 3 is 0.00031994268647395074
# Loss in episode 3 is 0.00013116262562107295
# Loss in episode 3 is 6.4964519879140425e-06
# Loss in episode 3 is 5.875019996892661e-05
# Loss in episode 3 is 1.5238965715980157e-05
# Loss in episode 3 is 3.3787000575102866e-05
# Loss in episode 3 is 2.631560346344486e-05
# Loss in episode 3 is 1.2298357432882767e-05
# Loss in episode 3 is 6.78804963172297e-06
# Loss in episode 3 is 4.9092937842942774e-05
# Loss in episode 3 is 4.432575951796025e-05
# Loss in episode 3 is 4.857433305005543e-05
# Loss in episode 3 is 5.9477151808096096e-05
# Loss in episode 3 is 0.00023018491629045457
# Loss in episode 3 is 1.8100904526363593e-06
# Loss in episode 3 is 0.0028085296507924795
# Loss in episode 3 is 5.269429948384641e-06
# Loss in episode 3 is 6.23728774371557e-05
# Loss in episode 3 is 0.00018333859043195844
# Loss in episode 3 is 5.68744471820537e-05
# Loss in episode 3 is 2.880741703847889e-05
# Loss in episode 3 is 0.00028003662009723485
# Loss in episode 3 is 4.837213964492548e-06
# Loss in episode 3 is 0.000739513779990375
# Loss in episode 3 is 3.9985665353015065e-05
# Loss in episode 3 is 0.0004079251375515014
# Loss in episode 3 is 2.8482506309046585e-07
# Loss in episode 3 is 9.655722533352673e-05
# Loss in episode 3 is 2.0744409994222224e-05
# Loss in episode 3 is 0.0007250250782817602
# Loss in episode 3 is 0.00016433114069513977
# Loss in episode 3 is 7.897280340785073e-08
# Loss in episode 3 is 6.108596426201984e-05
# Loss in episode 3 is 0.00012182286445749924
# Loss in episode 3 is 0.00012840409181080759
# Loss in episode 3 is 0.0013040120247751474
# Loss in episode 3 is 7.238086254801601e-05
# Loss in episode 3 is 4.2840696551138535e-05
# Loss in episode 3 is 0.00017333545838482678
# Loss in episode 3 is 9.229016541212332e-06
# Loss in episode 3 is 2.5734558221301995e-05
# Loss in episode 3 is 7.250430644489825e-05
# Loss in episode 3 is 9.133571438724175e-06
# Loss in episode 3 is 0.00033209274988621473
# Loss in episode 3 is 4.2380190279800445e-05
# Loss in episode 3 is 0.0001890036801341921
# Loss in episode 3 is 5.4204792832024395e-05
# Loss in episode 3 is 1.8945463580166688e-06
# Loss in episode 3 is 3.0356036404555198e-06
# Loss in episode 3 is 5.1450697355903685e-06
# Loss in episode 3 is 0.00013977086928207427
# Loss in episode 3 is 3.657432534964755e-05
# Loss in episode 3 is 3.928967998945154e-06
# Loss in episode 3 is 0.00034126712125726044
# Loss in episode 3 is 6.449126522056758e-05
# Loss in episode 3 is 1.9424702259129845e-05
# Loss in episode 3 is 0.0007013644790276885
# Loss in episode 3 is 0.0027191443368792534
# Loss in episode 3 is 9.43829036259558e-06
# Loss in episode 3 is 1.1725263902917504e-05
# Loss in episode 3 is 6.27208428340964e-05
# Loss in episode 3 is 2.1979456050758017e-06
# Loss in episode 3 is 7.987372555362526e-06
# Loss in episode 3 is 5.936981688137166e-05
# Loss in episode 3 is 0.0001109271397581324
# Loss in episode 3 is 3.481201929389499e-05
# Loss in episode 3 is 0.000459966657217592
# Loss in episode 3 is 6.661690804321552e-06
# Loss in episode 3 is 9.631272632759647e-07
# Loss in episode 3 is 0.0002526651369407773
# Loss in episode 3 is 0.0024221083149313927
# Loss in episode 3 is 0.00020700754248537123
# Loss in episode 3 is 5.151974255568348e-05
# Loss in episode 3 is 7.109736088750651e-06
# Loss in episode 3 is 0.00019739683193620294
# Loss in episode 3 is 6.180993659654632e-05
# Loss in episode 3 is 7.667365571251139e-05
# Loss in episode 3 is 0.00016651702753733844
# Loss in episode 3 is 0.0007829635287635028
# Loss in episode 3 is 2.6890036224358482e-06
# Loss in episode 3 is 0.00025844969786703587
# Loss in episode 3 is 0.00014923677372280508
# Loss in episode 3 is 1.1803154848166741e-05
# Loss in episode 3 is 0.00020982002024538815
# Loss in episode 3 is 0.00046464335173368454
# Loss in episode 3 is 3.510274571016936e-10
# Loss in episode 3 is 1.3001238130527781e-06
# Loss in episode 3 is 3.931783794541843e-06
# Loss in episode 3 is 0.00014594881213270128
# Loss in episode 3 is 0.00015653730952180922
# Loss in episode 3 is 3.867400664603338e-06
# Loss in episode 3 is 9.079037681658519e-07
# Loss in episode 3 is 6.673375173704699e-05
# Loss in episode 3 is 3.239984607716906e-06
# Loss in episode 3 is 2.597842012619367e-06
# Loss in episode 3 is 8.004916162462905e-05
# Loss in episode 3 is 7.324889338633511e-06
# Loss in episode 3 is 0.0002969343331642449
# Loss in episode 3 is 0.00048276595771312714
# Loss in episode 3 is 1.332423948952055e-07
# Loss in episode 3 is 0.00047756184358149767
# Loss in episode 3 is 6.476287580881035e-06
# Loss in episode 3 is 0.0003583960933610797
# Loss in episode 3 is 3.596695933083538e-06
# Loss in episode 3 is 7.451637065969408e-05
# Loss in episode 3 is 7.466687384294346e-05
# Loss in episode 3 is 2.224760282842908e-05
# Loss in episode 3 is 2.6140947738895193e-05
# Loss in episode 3 is 0.0004667169996537268
# Loss in episode 3 is 5.480523395817727e-05
# Loss in episode 3 is 0.00012043958122376353
# Loss in episode 3 is 0.0003338344977237284
# Loss in episode 3 is 8.534449443686754e-05
# Loss in episode 3 is 2.6100633476744406e-06
# Loss in episode 3 is 1.1740006584659568e-06
# Loss in episode 3 is 0.00013197587395552546
# Loss in episode 3 is 0.0002562737208791077
# Loss in episode 3 is 1.325470719848454e-07
# Loss in episode 3 is 0.00019614206394180655
# Loss in episode 3 is 1.0269423000863753e-07
# Loss in episode 3 is 4.563867150864098e-07
# Loss in episode 3 is 6.193442459334619e-06
# Loss in episode 3 is 1.001421878754627e-06
# Loss in episode 3 is 0.00020001790835522115
# Loss in episode 3 is 8.960472769103944e-05
# Loss in episode 3 is 0.0003679998917505145
# Loss in episode 3 is 0.0007410974358208477
# Loss in episode 3 is 0.00039009522879496217
# Loss in episode 3 is 8.373564924113452e-05
# Loss in episode 3 is 3.0771491310588317e-07
# Loss in episode 3 is 2.9458722565323114e-05
# Loss in episode 3 is 0.00027945832698605955
# Loss in episode 3 is 6.180056516313925e-05
# Loss in episode 3 is 8.009556609067658e-07
# Loss in episode 3 is 0.00040563629590906203
# Loss in episode 3 is 0.0025459551252424717
# Loss in episode 3 is 0.00015750715101603419
# Loss in episode 3 is 0.00021933348034508526
# Loss in episode 3 is 9.34363852138631e-05
# Loss in episode 3 is 1.969061258932925e-06
# Loss in episode 3 is 2.066977913273149e-06
# Loss in episode 3 is 1.6389520169468597e-05
# Loss in episode 3 is 5.669058737112209e-05
# Loss in episode 3 is 1.4499854842142668e-05
# Loss in episode 3 is 2.8423507956176763e-06
# Loss in episode 3 is 4.298210478737019e-05
# Loss in episode 3 is 0.00023845749092288315
# Loss in episode 3 is 3.3582568903511856e-06
# Loss in episode 3 is 1.637324021430686e-05
# Loss in episode 3 is 6.450207729358226e-05
# Loss in episode 3 is 0.00012454341049306095
# Loss in episode 3 is 0.00014740978076588362
# Loss in episode 3 is 1.7361911886837333e-05
# Loss in episode 3 is 4.439069471118273e-06
# Loss in episode 3 is 6.068145466997521e-06
# Loss in episode 3 is 2.164977922802791e-05
# Loss in episode 3 is 0.00011445029667811468
# Loss in episode 3 is 2.1223306248430163e-05
# Loss in episode 3 is 0.001781198661774397
# Loss in episode 3 is 3.2541316613787785e-05
# Loss in episode 3 is 2.471906555001624e-05
# Loss in episode 3 is 7.454890749158949e-08
# Loss in episode 3 is 0.0006675312761217356
# Loss in episode 3 is 7.77675086283125e-06
# Loss in episode 3 is 1.1363333214831073e-05
# Loss in episode 3 is 3.828384797088802e-05
# Loss in episode 3 is 0.00011726039519999176
# Loss in episode 3 is 8.967536996351555e-05
# Loss in episode 3 is 0.00012736573989968747
# Loss in episode 3 is 0.0012444979511201382
# Loss in episode 3 is 0.0002325312962057069
# Loss in episode 3 is 0.00035178230609744787
# Loss in episode 3 is 0.00016222120029851794
# Loss in episode 3 is 1.0000421752920374e-05
# Loss in episode 3 is 2.341163281016634e-06
# Loss in episode 3 is 0.00010438721074024215
# Loss in episode 3 is 8.26618997962214e-05
# Loss in episode 3 is 4.533968967734836e-05
# Loss in episode 3 is 7.252931027323939e-06
# Loss in episode 3 is 3.255076208574792e-08
# Loss in episode 3 is 2.9954819183330983e-05
# Loss in episode 3 is 3.4784457056957763e-06
# Loss in episode 3 is 0.00019811866513919085
# Loss in episode 3 is 5.373589715418348e-07
# Loss in episode 3 is 3.862744415528141e-05
# Loss in episode 3 is 8.343264198629186e-06
# Loss in episode 3 is 6.304177873062144e-07
# Loss in episode 3 is 0.00011180218280060217
# Loss in episode 3 is 1.239200537384022e-05
# Loss in episode 3 is 1.3701455259251816e-07
# Loss in episode 3 is 2.6007469386968296e-06
# Loss in episode 3 is 3.1708702863397775e-06
# Loss in episode 3 is 1.0568169273028616e-05
# Loss in episode 3 is 5.245906868367456e-05
# Loss in episode 3 is 8.022999509194051e-08
# Loss in episode 3 is 5.005101115784782e-07
# Loss in episode 3 is 0.0001035773238982074
# Loss in episode 3 is 2.086726453853771e-05
# Loss in episode 3 is 2.6271483875461854e-05
# Loss in episode 3 is 1.0290285899827722e-05
# Loss in episode 3 is 4.158382580499165e-05
# Loss in episode 3 is 0.00030067662009969354
# Loss in episode 3 is 5.511952986125834e-05
# Loss in episode 3 is 0.0008421590318903327
# Loss in episode 3 is 0.0005163493333384395
# Loss in episode 3 is 2.2892483684699982e-05
# Loss in episode 3 is 2.5159100914606825e-05
# Loss in episode 3 is 2.7362922992324457e-05
# Loss in episode 3 is 1.3443752322928049e-05
# Loss in episode 3 is 0.0001817746233427897
# Loss in episode 3 is 0.0006590795237571001
# Loss in episode 3 is 0.00011741227353923023
# Loss in episode 3 is 0.001074243918992579
# Loss in episode 3 is 0.001234406721778214
# ...
# Loss in episode 8 is 1.932035775098484e-05
# Loss in episode 8 is 1.9589850808188203e-07
# Loss in episode 8 is 1.5546866052318364e-05
# Loss in episode 8 is 7.759455183986574e-05
# Loss in episode 8 is 8.94170534593286e-06
# Loss in episode 8 is 0.0003546585503499955
# Loss in episode 8 is 6.583744834642857e-05
# Loss in episode 8 is 3.944105174014112e-06
# Loss in episode 8 is 7.157975687732687e-07
# Loss in episode 8 is 1.240090625742596e-07
# Loss in episode 8 is 0.0001247165200766176
# Loss in episode 8 is 6.8985580583103e-05
# Loss in episode 8 is 0.00020133434736635536
# Loss in episode 8 is 1.442491139869162e-07
# Loss in episode 8 is 0.00030712655279785395
# Loss in episode 8 is 0.0003647289995569736
# Loss in episode 8 is 2.787575613183435e-05
# Loss in episode 8 is 0.0274985209107399
# Loss in episode 8 is 5.9103899729961995e-06
# Loss in episode 8 is 1.6349458746844903e-06
# Loss in episode 8 is 3.720132008311339e-05
# Loss in episode 8 is 2.0853927708230913e-05
# Loss in episode 8 is 6.899626168888062e-05
# Loss in episode 8 is 1.9463354874460492e-06
# Loss in episode 8 is 5.182544919080101e-05
# Loss in episode 8 is 8.008685108507052e-05
# Loss in episode 8 is 1.385055384162115e-06
# Loss in episode 8 is 5.3456519708561245e-06
# Loss in episode 8 is 2.559729000495281e-05
# Loss in episode 8 is 3.1942456644173944e-06
# Loss in episode 8 is 7.53212134441128e-06
# Loss in episode 8 is 1.690890343297724e-07
# Loss in episode 8 is 2.322568980162032e-05
# Loss in episode 8 is 0.00012795624206773937
# Loss in episode 8 is 1.9034558818020741e-07
# Loss in episode 8 is 3.845858373097144e-06
# Loss in episode 8 is 1.9922554201912135e-06
# Loss in episode 8 is 0.00021435570670291781
# Loss in episode 8 is 1.7050055248546414e-05
# Loss in episode 8 is 1.7657849866736797e-06
# Loss in episode 8 is 0.00018300260126125067
# Loss in episode 8 is 1.83162610483123e-05
# Loss in episode 8 is 8.770289809945098e-07
# Loss in episode 8 is 2.314404810022097e-05
# Loss in episode 8 is 1.2784582395397592e-05
# Loss in episode 8 is 2.307543581991922e-05
# Loss in episode 8 is 1.230925704476249e-06
# Loss in episode 8 is 6.536582986882422e-06
# Loss in episode 8 is 9.027523333315912e-07
# Loss in episode 8 is 0.0002125489991158247
# Loss in episode 8 is 2.548544216551818e-06
# Loss in episode 8 is 0.0032193639781326056
# Loss in episode 8 is 5.146895091456827e-06
# Loss in episode 8 is 4.708424603450112e-05
# Loss in episode 8 is 1.9486307792249136e-05
# Loss in episode 8 is 7.613497473357711e-06
# Loss in episode 8 is 3.315507638035342e-05
# Loss in episode 8 is 2.8348149498924613e-05
# Loss in episode 8 is 1.3354607290239073e-05
# Loss in episode 8 is 2.700133336475119e-05
# Loss in episode 8 is 4.524094038060866e-06
# Loss in episode 8 is 9.189643890294974e-08
# Loss in episode 8 is 7.319432370422874e-06
# Loss in episode 8 is 1.4752309652976692e-05
# Loss in episode 8 is 2.13167404581327e-05
# Loss in episode 8 is 1.5388017345685512e-05
# Loss in episode 8 is 6.196632512001088e-06
# Loss in episode 8 is 0.0006114765419624746
# Loss in episode 8 is 3.786924935411662e-06
# Loss in episode 8 is 3.148908945149742e-05
# Loss in episode 8 is 2.6813529984792694e-05
# Loss in episode 8 is 5.8630241255741566e-05
# Loss in episode 9 is 9.601268402548158e-07
# Loss in episode 9 is 2.427244680802687e-06
# Loss in episode 9 is 2.960134770546574e-05
# Loss in episode 9 is 9.820410923566669e-05
# Loss in episode 9 is 1.9164630430168472e-05
# Loss in episode 9 is 4.185014290669642e-08
# Loss in episode 9 is 3.6024628116138047e-06
# Loss in episode 9 is 9.160923946183175e-05
# Loss in episode 9 is 2.4834230316628236e-07
# Loss in episode 9 is 2.800564118388138e-07
# Loss in episode 9 is 2.5069937237276463e-07
# Loss in episode 9 is 7.573865332233254e-06
# Loss in episode 9 is 3.152570116071729e-06
# Loss in episode 9 is 0.00011031246685888618
# Loss in episode 9 is 3.512938928906806e-05
# Loss in episode 9 is 5.328061888576485e-06
# Loss in episode 9 is 0.00010321356967324391
# Loss in episode 9 is 6.774196663172916e-06
# Loss in episode 9 is 1.966782747331308e-06
# Loss in episode 9 is 0.00020523816056083888
# Loss in episode 9 is 2.475804876667098e-07
# Loss in episode 9 is 4.394209463498555e-05
# Loss in episode 9 is 2.0190603322589595e-07
# Loss in episode 9 is 1.2752209840982687e-05
# Loss in episode 9 is 3.597714385250583e-05
# Loss in episode 9 is 2.3082593543222174e-05
# Loss in episode 9 is 8.819480257216128e-09
# Loss in episode 9 is 7.193535566329956e-06
# Loss in episode 9 is 6.548329452016333e-07
# Loss in episode 9 is 6.455945822381182e-06
# Loss in episode 9 is 3.473344349913532e-07
# Loss in episode 9 is 5.833373052155366e-06
# Loss in episode 9 is 2.652587863849476e-05
# Loss in episode 9 is 4.6414730604738e-05
# Loss in episode 9 is 1.3426983969111461e-05
# Loss in episode 9 is 3.8151381886564195e-05
# Loss in episode 9 is 1.6054426623668405e-06
# Loss in episode 9 is 3.734832353075035e-05
# Loss in episode 9 is 4.98270651405619e-07
# Loss in episode 9 is 7.487638504244387e-05
# Loss in episode 9 is 1.1020836154784774e-06
# Loss in episode 9 is 1.3587533658210305e-06
# Loss in episode 9 is 1.1524210918878453e-07
# Loss in episode 9 is 1.7357501747028437e-06
# Loss in episode 9 is 9.75328657659702e-06
# Loss in episode 9 is 0.00016523501835763454
# Loss in episode 9 is 1.9392182366573252e-05
# Loss in episode 9 is 0.00017320786719210446
# Loss in episode 9 is 2.55800478043966e-06
# Loss in episode 9 is 1.1179352441104129e-05
# Loss in episode 9 is 4.041893589601386e-06
# Loss in episode 9 is 0.00010299353743903339
# Loss in episode 9 is 0.00011280915350653231
# Loss in episode 9 is 2.8134245440014638e-05
# Loss in episode 9 is 2.6558320314507e-05
# Loss in episode 9 is 1.8145006833947264e-05
# Loss in episode 9 is 1.5028642337711062e-05
# Loss in episode 9 is 0.00034078542375937104
# Loss in episode 9 is 2.6561262984614586e-06
# Loss in episode 9 is 1.6636411601211876e-05
# Loss in episode 9 is 5.0809607188284645e-08
# Loss in episode 9 is 1.3310295798873994e-06
# Loss in episode 9 is 1.2995591532671824e-05
# Loss in episode 9 is 1.5904522143728173e-09
# Loss in episode 9 is 2.1627127352985553e-05
# Loss in episode 9 is 5.1824590627802536e-05
# Loss in episode 9 is 0.00015158246969804168
# Loss in episode 9 is 3.1640116503695026e-05
# Loss in episode 9 is 1.6313998685291153e-07
# Loss in episode 9 is 6.478898058048799e-07
# Loss in episode 9 is 5.3159466915531084e-05
# Loss in episode 9 is 6.371399763338559e-07
# Loss in episode 9 is 0.00035230821231380105
# Loss in episode 9 is 1.6537207557121292e-05
# Loss in episode 9 is 2.6028970978586585e-07
# Loss in episode 9 is 4.235881715430878e-05
# Loss in episode 9 is 0.0001270329230464995
# Loss in episode 9 is 1.6023596893788294e-09
# Loss in episode 9 is 0.00011979554255958647
# Loss in episode 9 is 0.0007417144370265305
# Loss in episode 9 is 8.02482754806988e-05
# Loss in episode 9 is 3.6760111470357515e-06
# Loss in episode 9 is 7.315669790841639e-06
# Loss in episode 9 is 4.402402737468947e-06
# Loss in episode 9 is 4.304971753299469e-06
# Loss in episode 9 is 1.5120957868930418e-05
# Loss in episode 9 is 5.737483661505394e-06
# Loss in episode 9 is 6.916609436302679e-06
# Loss in episode 9 is 6.717606447637081e-05
# Loss in episode 9 is 1.425909431418404e-06
# Loss in episode 9 is 9.498214785708115e-05
# Loss in episode 9 is 4.943296616488624e-08
# Loss in episode 9 is 0.0052787549793720245
# Loss in episode 9 is 7.821361577953212e-06
# Loss in episode 9 is 1.5264609828591347e-05
# Loss in episode 9 is 5.162625598131854e-07
# Loss in episode 9 is 7.661263225600123e-06
# Loss in episode 9 is 1.0880437912419438e-05
# Loss in episode 9 is 0.00016046220844145864
# Loss in episode 9 is 3.7022007745690644e-05
# Loss in episode 9 is 0.00016996689373627305
# Loss in episode 9 is 9.613536349206697e-07
# Loss in episode 9 is 0.00013784138718619943
# Loss in episode 9 is 5.17092530571972e-06
# Loss in episode 9 is 1.2453611816454213e-05
# Loss in episode 9 is 1.6815009075799026e-05
# Loss in episode 9 is 1.264363946873459e-09
# Loss in episode 9 is 3.056180867133662e-05
# Loss in episode 9 is 2.91076758003328e-05
# Loss in episode 9 is 1.208970275001775e-06
# Loss in episode 9 is 1.4841800748399692e-06
# Loss in episode 9 is 8.129075467877556e-06
# Loss in episode 9 is 3.380318230483681e-05
# Loss in episode 9 is 3.4364779821771663e-06
# Loss in episode 9 is 2.6576145728540723e-07
# Loss in episode 9 is 4.967641871189699e-07
# Loss in episode 9 is 3.0560922823497094e-06
# Loss in episode 9 is 4.8929920012596995e-05
# Loss in episode 9 is 2.427997242193669e-05
# Loss in episode 9 is 5.582281801252975e-07
# Loss in episode 9 is 0.00011124758020741865
# Loss in episode 9 is 1.1441031347203534e-05
# Loss in episode 9 is 9.636636377763352e-07
# Loss in episode 9 is 2.686098014237359e-05
# Loss in episode 9 is 5.175591013539815e-06
# Loss in episode 9 is 1.4690302805320243e-06
# Loss in episode 9 is 0.00011506395821925253
# Loss in episode 9 is 8.450248060398735e-06
# Loss in episode 9 is 8.696646546013653e-05
# Loss in episode 9 is 5.5371128837578e-05
# Loss in episode 9 is 5.437739673652686e-05
# Loss in episode 9 is 0.00014104414731264114
# Loss in episode 9 is 8.297673048218712e-06
# Loss in episode 9 is 2.082768696709536e-05
# Loss in episode 9 is 1.1662503311526962e-05
# Loss in episode 9 is 3.799568446538615e-07
# Loss in episode 9 is 5.636084824800491e-05
# Loss in episode 9 is 1.1466177966212854e-05
# Loss in episode 9 is 2.3326438167714514e-06
# Loss in episode 9 is 2.518192741263192e-05
# Loss in episode 9 is 1.7740423572831787e-05
# Loss in episode 9 is 4.9802809371612966e-05
# Loss in episode 9 is 0.00011525499576237053
# Loss in episode 9 is 5.441856956167612e-07
# Loss in episode 9 is 3.691947858897038e-05
# Loss in episode 9 is 5.337280981621007e-07
# Loss in episode 9 is 2.006769136642106e-05
# Loss in episode 9 is 0.00010400380415376276
# Loss in episode 9 is 0.004973213654011488
# Loss in episode 9 is 0.00024909828789532185
# Loss in episode 9 is 1.9022729247808456e-05
# Loss in episode 9 is 1.3711195379073615e-06
# Loss in episode 9 is 1.6994519683066756e-05
# Loss in episode 9 is 9.055823824155596e-08
# Loss in episode 9 is 6.992043199716136e-05
# Loss in episode 9 is 9.397041139891371e-05
# Loss in episode 9 is 0.0007933535380288959
# Loss in episode 9 is 7.809897215338424e-05
# Loss in episode 9 is 2.1617165657517035e-06
# Loss in episode 9 is 9.201091415889096e-06
# Loss in episode 9 is 6.0102178395027295e-05
# Loss in episode 9 is 3.864783138851635e-06
# Loss in episode 9 is 7.3596261245256756e-06
# Loss in episode 9 is 4.408507834341435e-07
# Loss in episode 9 is 3.7866466300329193e-05
# Loss in episode 9 is 1.5209081539069302e-05
# Loss in episode 9 is 0.0001143492991104722
# Loss in episode 9 is 1.5994861314538866e-05
# Loss in episode 9 is 2.0458373910514638e-05
# Loss in episode 9 is 4.790157618117519e-06
# Loss in episode 9 is 3.075768290727865e-06
# Loss in episode 9 is 1.4069551980355754e-05
# Loss in episode 9 is 2.1524005205719732e-05
# Loss in episode 9 is 3.7805119063705206e-05
# Loss in episode 9 is 0.0001421771594323218
# Loss in episode 9 is 5.516933924809564e-06
# Loss in episode 9 is 7.33577564915322e-07
# Loss in episode 9 is 1.566746732351021e-10
# Loss in episode 9 is 6.693307659588754e-05
# Loss in episode 9 is 3.226088892915868e-06
# Loss in episode 9 is 5.71083182876464e-05
# Loss in episode 9 is 1.2839997907576617e-05
# Loss in episode 9 is 5.565972242038697e-05
# Loss in episode 9 is 1.7567504983162507e-05
# Loss in episode 9 is 4.127212378080003e-05
# Loss in episode 9 is 7.037237537588226e-06
# Loss in episode 9 is 3.0749974939681124e-06
# Loss in episode 9 is 6.876698989799479e-06
# Loss in episode 9 is 7.87894896348007e-06
# Loss in episode 9 is 1.7925083739100955e-05
# Loss in episode 9 is 0.00021124498744029552
# Loss in episode 9 is 2.6262378014507703e-05
# Loss in episode 9 is 5.481678090291098e-05
# Loss in episode 9 is 5.518562829820439e-05
# Loss in episode 9 is 0.00016652265912853181
# Loss in episode 9 is 7.976145752763841e-06
# Loss in episode 9 is 3.3059232009691186e-06
# Loss in episode 9 is 1.6718806364224292e-05
# Loss in episode 9 is 4.381413964438252e-05
# Loss in episode 9 is 6.38408018858172e-05
# Loss in episode 9 is 5.661418254021555e-05
# Loss in episode 9 is 8.024179260246456e-05
# Loss in episode 9 is 2.6314643037039787e-05
# Loss in episode 9 is 6.602623443541233e-07
# Loss in episode 9 is 4.6188957639969885e-05
# Loss in episode 9 is 1.098149823519634e-05
# Loss in episode 9 is 0.00022381864255294204
# Loss in episode 9 is 1.5776457757965545e-06
# Loss in episode 9 is 4.472809905564645e-06
# Loss in episode 9 is 1.1004781299561728e-06
# Loss in episode 9 is 1.1702560186677147e-05
# Loss in episode 9 is 1.3813050827593543e-06
# Loss in episode 9 is 1.845591214078013e-05
# Loss in episode 9 is 1.3375961316342e-05
# Loss in episode 9 is 2.165343175875023e-05
# Loss in episode 9 is 9.872399004962062e-07
# Loss in episode 9 is 7.92746777733555e-06
# Loss in episode 9 is 3.1965896596375387e-06
# Loss in episode 9 is 4.0055811041384e-06
# Loss in episode 9 is 1.829350003390573e-05
# Loss in episode 9 is 1.4128832845017314e-05
# Loss in episode 9 is 4.128103014977569e-08
# Loss in episode 9 is 5.400952886702726e-06
# Loss in episode 9 is 6.35115648037754e-05
# Loss in episode 9 is 9.774979844223708e-06
# Loss in episode 9 is 0.0003308999876026064
# Loss in episode 9 is 4.2212381231365725e-05
# Loss in episode 9 is 9.971946610676241e-07
# Loss in episode 9 is 1.4237206968914506e-09
# Loss in episode 9 is 2.3652575009691645e-07
# Loss in episode 9 is 0.00016973301535472274
# Loss in episode 9 is 6.278915680013597e-05
# Loss in episode 9 is 0.0001290638028876856
# Loss in episode 9 is 2.604056703603419e-07
# Loss in episode 9 is 0.00023234757827594876
# Loss in episode 9 is 0.0002882042608689517
# Loss in episode 9 is 1.0277128239977174e-05
# Loss in episode 9 is 0.023067669942975044
# Loss in episode 9 is 4.5434908315655775e-06
# Loss in episode 9 is 7.0910737122176215e-06
# Loss in episode 9 is 5.6723871239228174e-05
# Loss in episode 9 is 2.1748619474237785e-05
# Loss in episode 9 is 4.218275353196077e-05
# Loss in episode 9 is 1.097070381206322e-07
# Loss in episode 9 is 3.349069447722286e-05
# Loss in episode 9 is 3.468264185357839e-05
# Loss in episode 9 is 4.873221541856765e-07
# Loss in episode 9 is 2.674278221093118e-06
# Loss in episode 9 is 2.2050611732993275e-05
# Loss in episode 9 is 5.76458944578917e-07
# Loss in episode 9 is 2.2670294129056856e-05
# Loss in episode 9 is 1.4031508044354268e-06
# Loss in episode 9 is 3.0720591894350946e-05
# Loss in episode 9 is 6.679953366983682e-05
# Loss in episode 9 is 2.842987356643789e-08
# Loss in episode 9 is 4.327519491198473e-06
# Loss in episode 9 is 5.3989906518836506e-06
# Loss in episode 9 is 0.00013082686928100884
# Loss in episode 9 is 2.0162135115242563e-05
# Loss in episode 9 is 1.5562571675786785e-08
# Loss in episode 9 is 0.00017156271496787667
# Loss in episode 9 is 2.0533509086817503e-05
# Loss in episode 9 is 1.1643546713457908e-06
# Loss in episode 9 is 1.1502486813697033e-05
# Loss in episode 9 is 7.791302778059617e-06
# Loss in episode 9 is 1.3488135664374568e-05
# Loss in episode 9 is 3.568125634956232e-07
# Loss in episode 9 is 3.5638197459775256e-06
# Loss in episode 9 is 3.286084620413021e-06
# Loss in episode 9 is 0.00014373339945450425
# Loss in episode 9 is 2.3882746518211206e-06
# Loss in episode 9 is 0.002400426659733057
# Loss in episode 9 is 7.260851816681679e-06
# Loss in episode 9 is 5.868338485015556e-05
# Loss in episode 9 is 2.356795630475972e-05
# Loss in episode 9 is 4.3414024730736855e-06
# Loss in episode 9 is 3.6589644878404215e-05
# Loss in episode 9 is 5.038548988522962e-05
# Loss in episode 9 is 1.0753228707471862e-05
# Loss in episode 9 is 2.531003519834485e-05
# Loss in episode 9 is 6.352427590172738e-06
# Loss in episode 9 is 2.3582257924203986e-08
# Loss in episode 9 is 8.048215931921732e-06
# Loss in episode 9 is 1.1701362382154912e-05
# Loss in episode 9 is 3.47352288372349e-05
# Loss in episode 9 is 1.43677252708585e-05
# Loss in episode 9 is 1.4545851456659875e-07
# Loss in episode 9 is 0.0006854749517515302
# Loss in episode 9 is 1.4993746844993439e-05
# Loss in episode 9 is 2.766267061815597e-05
# Loss in episode 9 is 3.7447789509315044e-05
# Loss in episode 9 is 5.5838409025454894e-05
# . . .
# . . .
# . . .
# . X .
# . . .
# . . .
# . X .
# . . .
# . O .
# . X .
# . . .
# . O X
# . X .
# . O .
# . O X
# . X .
# . O .
# . O X
# O X .
# . O .
# . O X
# O X .
# . O .
# . O X
# O X .
# . O .
# O O X
# O X .
# . O .
# O O X
# O X O
# . O .
# O O X
# Winner: -1

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import random

# Set up the Tic-Tac-Toe environment
class TicTacToe:
    def __init__(self):
        self.board = np.zeros((3, 3), dtype=int)  # 3x3 board
        self.current_player = 1  # Player 1 starts

    def reset(self):
        self.board = np.zeros((3, 3), dtype=int)
        self.current_player = 1
        return self.board.flatten()

    def step(self, action):
        row, col = divmod(action, 3)
        if self.board[row, col] == 0:
            self.board[row, col] = self.current_player
            reward, done = self.check_game_state()
            self.current_player = -self.current_player  # Switch player
            return self.board.flatten(), reward, done
        else:
            return self.board.flatten(), -10, False  # Invalid move penalty

    def check_game_state(self):
        # Check rows, columns, diagonals for a win
        for i in range(3):
            if abs(sum(self.board[i, :])) == 3 or abs(sum(self.board[:, i])) == 3:
                return 1, True
        if abs(self.board.trace()) == 3 or abs(np.fliplr(self.board).trace()) == 3:
            return 1, True
        if not np.any(self.board == 0):  # Draw
            return 0.5, True
        return 0, False  # Continue

# Define the MLP model for the RL agent
class MLP(nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(9, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, 9)
        )

    def forward(self, x):
        return self.layers(x)

# Q-learning with self-play
class QLearningAgent:
    def __init__(self, model, lr=0.001, gamma=0.9, epsilon=0.1):
        self.model = model
        self.optimizer = optim.Adam(model.parameters(), lr=lr)
        self.loss_fn = nn.MSELoss()
        self.gamma = gamma
        self.epsilon = epsilon

    def choose_action(self, state):
        if random.random() < self.epsilon:  # Explore
            return random.choice([i for i, x in enumerate(state) if x == 0])
        else:  # Exploit
            with torch.no_grad():
                q_values = self.model(torch.FloatTensor(state))
            q_values[state != 0] = -float('inf')  # Mask invalid moves
            return q_values.argmax().item()

    def update(self, state, action, reward, next_state, done):
        self.optimizer.zero_grad()
        q_values = self.model(torch.FloatTensor(state))
        target_q_values = q_values.clone().detach()
        next_q_value = self.model(torch.FloatTensor(next_state)).max().item()
        
        if done:
            target_q_values[action] = reward
        else:
            target_q_values[action] = reward + self.gamma * next_q_value

        loss = self.loss_fn(q_values, target_q_values)
        
        loss.backward()
        self.optimizer.step()
        return loss

# Training loop with self-play
def train_self_play(num_episodes=10):
    env = TicTacToe()
    model = MLP()
    agent1 = QLearningAgent(model)
    agent2 = QLearningAgent(model)  # Agent 2 can be the same model in self-play

    for episode in range(num_episodes):
        state = env.reset()
        done = False
        while not done:
            action1 = agent1.choose_action(state)
            next_state, reward, done = env.step(action1)
            agent1.update(state, action1, reward, next_state, done)
            state = next_state
            
            if done: break

            action2 = agent2.choose_action(state)
            next_state, reward, done = env.step(action2)
            loss = agent2.update(state, action2, -reward, next_state, done)  # Reverse reward for player 2
            print(f"Loss after {episode+1} episodes = {loss}")
            state = next_state
    
    return model, agent1, agent2

model, agent, _ =  train_self_play()
# Out:
# Loss after 1 episodes = 9.316454452346079e-06
# Loss after 1 episodes = 0.0015216395258903503
# Loss after 1 episodes = 7.319499854929745e-05
# Loss after 1 episodes = 0.0030293120071291924
# Loss after 2 episodes = 4.3247780467936536e-07
# Loss after 2 episodes = 0.00011930424807360396
# Loss after 2 episodes = 0.0010923356749117374
# Loss after 3 episodes = 9.120473987422884e-05
# Loss after 3 episodes = 0.0004205180157441646
# Loss after 3 episodes = 0.004507248755544424
# Loss after 3 episodes = 0.0015313895419239998
# Loss after 4 episodes = 2.6358857212471776e-06
# Loss after 4 episodes = 1.3017472156207077e-05
# Loss after 4 episodes = 0.0019664056599140167
# Loss after 4 episodes = 0.006467882543802261
# Loss after 5 episodes = 0.0004816065775230527
# Loss after 5 episodes = 0.0006575168808922172
# Loss after 5 episodes = 0.001357520930469036
# Loss after 5 episodes = 0.003865249454975128
# Loss after 6 episodes = 0.00010207647574134171
# Loss after 6 episodes = 3.451931843301281e-05
# Loss after 6 episodes = 0.00014332664432004094
# Loss after 7 episodes = 2.2912687200005166e-05
# Loss after 7 episodes = 7.5299126365280244e-06
# Loss after 7 episodes = 0.0007570803281851113
# Loss after 7 episodes = 0.016413316130638123
# Loss after 8 episodes = 2.9641465516760945e-05
# Loss after 8 episodes = 0.00019981768855359405
# Loss after 8 episodes = 0.00029891030862927437
# Loss after 8 episodes = 0.008000739850103855
# Loss after 9 episodes = 1.4101641454544733e-06
# Loss after 9 episodes = 0.0029292425606399775
# Loss after 9 episodes = 0.0003169423434883356
# Loss after 9 episodes = 0.2344404011964798
# Loss after 10 episodes = 3.767537054955028e-05
# Loss after 10 episodes = 0.00020582064462359995
# Loss after 10 episodes = 3.579955955501646e-05
# Loss after 10 episodes = 0.006415802985429764

# %%
model
# Out:
# MLP(
#   (layers): Sequential(
#     (0): Linear(in_features=9, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=9, bias=True)
#   )
# )

# %%
env = TicTacToe()
def display_board(board):
    """Displays the Tic-Tac-Toe board in a user-friendly way."""
    symbols = {1: "X", -1: "O", 0: " "}
    print("\nBoard:")
    for row in board:
        print(" | ".join(symbols[cell] for cell in row))
        print("-" * 9)

def get_human_move(board):
    """Get a valid move from the human player."""
    while True:
        try:
            move = int(input("Enter your move (0-8): "))
            if 0 <= move <= 8 and board.flatten()[move] == 0:
                return move
            else:
                print("Invalid move! Try again.")
        except ValueError:
            print("Please enter a number between 0 and 8.")

# Game loop
state = env.reset()
done = False
print("Welcome to Tic-Tac-Toe! You are 'X', and the model is 'O'.")
display_board(env.board)

while not done:
    # Human turn
    human_move = get_human_move(env.board)
    _, reward, done = env.step(human_move)  # Human move
    display_board(env.board)
    if done:
        if reward == 1:
            print("Congratulations! You win!")
        elif reward == 0.5:
            print("It's a draw!")
        break

    # Model's turn
    state = env.board.flatten()
    model_move = agent.choose_action(state)
    _, reward, done = env.step(model_move)  # Model move
    print("Model's move:")
    display_board(env.board)
    if done:
        if reward == 1:
            print("Model wins! Better luck next time.")
        elif reward == 0.5:
            print("It's a draw!")
        break
# Out:
# Welcome to Tic-Tac-Toe! You are 'X', and the model is 'O'.
#
# Board:
#   |   |
# ---------
#   |   |
# ---------
#   |   |
# ---------
#
# Board:
#   |   |
# ---------
#   | X |
# ---------
#   |   |
# ---------
# Model's move:
#
# Board:
#   |   |
# ---------
#   | X |
# ---------
# O |   |
# ---------
#
# Board:
# X |   |
# ---------
#   | X |
# ---------
# O |   |
# ---------
# Model's move:
#
# Board:
# X |   |
# ---------
#   | X | O
# ---------
# O |   |
# ---------
#
# Board:
# X |   |
# ---------
#   | X | O
# ---------
# O |   | X
# ---------
# Congratulations! You win!
